# %%
import json
from pathlib import Path

import pandas as pd

from elsapy.elsclient import ElsClient
from elsapy.elsprofile import ElsAuthor, ElsAffil
from elsapy.elsdoc import FullDoc, AbsDoc
from elsapy.elssearch import ElsSearch

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Init

# %%
# Load configuration
con_file = open("config.json")
config = json.load(con_file)
con_file.close()

# %%
# Initialize client
client = ElsClient(config['scopusapikey'])
client.inst_token = config['scopusinsttoken']

# %% [markdown]
# ## Author

# %%
## Author example

# Initialize author with uri
my_auth = ElsAuthor(
    #uri = 'https://api.elsevier.com/content/author/author_id/56767767900'
    author_id = '56767767900'
)

# %%
# Read author data, then write to disk
if my_auth.read(client):
    print ("my_auth.full_name: ", my_auth.full_name)
    my_auth.write()
else:
    print ("Read author failed.")
# Out:
# my_auth.full_name:  Jaime Andrés Castañeda

# %%
## Affiliation example

# Initialize affiliation with ID as string
my_aff = ElsAffil(affil_id = '128781065')
if my_aff.read(client):
    print ("my_aff.name: ", my_aff.name)
    my_aff.write()
else:
    print ("Read affiliation failed.")
# Out:
# my_aff.name:  Data Science Consultant

# %% [markdown]
# ## Scopus doc `AbsDoc`

# %%
## Scopus (Abtract) document example

# Initialize document with ID as integer
scp_doc = AbsDoc(scp_id = 85060921433)
if scp_doc.read(client):
    print ("scp_doc.title: ", scp_doc.title)
    scp_doc.write()   
else:
    print ("Read document failed.")
# Out:
# scp_doc.title:  A behavioral investigation of supply chain contracts for a newsvendor problem in a developing economy

# %% [markdown]
# ## ScienceDirect doc `FullDoc`

# %%
## ScienceDirect (full-text) document example using PII
pii_doc = FullDoc(sd_pii = 'S0925527318305024')
if pii_doc.read(client):
    print ("pii_doc.title: ", pii_doc.title)
    pii_doc.write()   
else:
    print ("Read document failed.")
# Out:
# pii_doc.title:  A behavioral investigation of supply chain contracts for a newsvendor problem in a developing economy

# %%
## ScienceDirect (full-text) document example using DOI
doi_doc = FullDoc(doi = '10.1016/j.ijpe.2018.12.024')
if doi_doc.read(client):
    print ("doi_doc.title: ", doi_doc.title)
    doi_doc.write()   
else:
    print ("Read document failed.")
# Out:
# doi_doc.title:  A behavioral investigation of supply chain contracts for a newsvendor problem in a developing economy

# %% [markdown]
# ## Scopus search `ElsSearch`

# %% [markdown]
# ### General search exploration

# %% [markdown]
# Papers from `castaneda` published after `2022`.

# %%
doc_srch = ElsSearch("AUTHOR-NAME(castaneda) AND PUBYEAR > 2022", 'scopus')
doc_srch.execute(client, get_all = False)
print ("doc_srch has", len(doc_srch.results), "results.")
# Out:
# doc_srch has 25 results.

# %%
doc_srch.results
# Out:
# [{'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85179485333'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85179485333?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85179485333&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85179485333&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'full-text',
#     '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0006899323004730'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85179485333',
#   'dc:identifier': 'SCOPUS_ID:85179485333',
#   'eid': '2-s2.0-85179485333',
#   'dc:title': 'Brain structural change associated with Cognitive Behavioral Therapy in maltreated children',
#   'dc:creator': 'González-Alemañy E.',
#   'prism:publicationName': 'Brain Research',
#   'prism:issn': '00068993',
#   'prism:eIssn': '18726240',
#   'prism:volume': '1825',
#   'prism:pageRange': None,
#   'prism:coverDate': '2024-02-15',
#   'prism:coverDisplayDate': '15 February 2024',
#   'prism:doi': '10.1016/j.brainres.2023.148702',
#   'pii': 'S0006899323004730',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'Cuban Neuroscience Center',
#     'affiliation-city': 'Havana',
#     'affiliation-country': 'Cuba'}],
#   'pubmed-id': '38070819',
#   'prism:aggregationType': 'Journal',
#   'subtype': 'ar',
#   'subtypeDescription': 'Article',
#   'article-number': '148702',
#   'source-id': '14346',
#   'openaccess': '0',
#   'openaccessFlag': False},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85178631266'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85178631266?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85178631266&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85178631266&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'full-text',
#     '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S1751616123006100'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85178631266',
#   'dc:identifier': 'SCOPUS_ID:85178631266',
#   'eid': '2-s2.0-85178631266',
#   'dc:title': 'Design and optimization methodology for different 3D processed materials (PLA, ABS and carbon fiber reinforced nylon PA12) subjected to static and dynamic loads',
#   'dc:creator': 'Rodríguez-Reyna S.L.',
#   'prism:publicationName': 'Journal of the Mechanical Behavior of Biomedical Materials',
#   'prism:issn': '17516161',
#   'prism:eIssn': '18780180',
#   'prism:volume': '150',
#   'prism:pageRange': None,
#   'prism:coverDate': '2024-02-01',
#   'prism:coverDisplayDate': 'February 2024',
#   'prism:doi': '10.1016/j.jmbbm.2023.106257',
#   'pii': 'S1751616123006100',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'Universidad Autónoma de Luis Potosí',
#     'affiliation-city': 'San Luis Potosí',
#     'affiliation-country': 'Mexico'}],
#   'prism:aggregationType': 'Journal',
#   'subtype': 'ar',
#   'subtypeDescription': 'Article',
#   'article-number': '106257',
#   'source-id': '8000153139',
#   'openaccess': '0',
#   'openaccessFlag': False},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85179802850'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85179802850?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85179802850&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85179802850&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'full-text',
#     '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S2405844023106906'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85179802850',
#   'dc:identifier': 'SCOPUS_ID:85179802850',
#   'eid': '2-s2.0-85179802850',
#   'dc:title': 'Impact on the first year of life of newborns with gestational infection by SARS-COV-2. Analysis of auditory effects',
#   'dc:creator': 'Sanz López L.',
#   'prism:publicationName': 'Heliyon',
#   'prism:issn': '24058440',
#   'prism:volume': '10',
#   'prism:issueIdentifier': '1',
#   'prism:pageRange': None,
#   'prism:coverDate': '2024-01-15',
#   'prism:coverDisplayDate': '15 January 2024',
#   'prism:doi': '10.1016/j.heliyon.2023.e23482',
#   'pii': 'S2405844023106906',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'Universidad Francisco de Vitoria',
#     'affiliation-city': 'Pozuelo de Alarcon',
#     'affiliation-country': 'Spain'}],
#   'prism:aggregationType': 'Journal',
#   'subtype': 'ar',
#   'subtypeDescription': 'Article',
#   'article-number': 'e23482',
#   'source-id': '21100411756',
#   'openaccess': '1',
#   'openaccessFlag': True},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85179664966'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85179664966?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85179664966&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85179664966&origin=inward'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85179664966',
#   'dc:identifier': 'SCOPUS_ID:85179664966',
#   'eid': '2-s2.0-85179664966',
#   'dc:title': 'Developing the DALI Data Literacy Framework for critical citizenry',
#   'dc:creator': 'Castañeda L.',
#   'prism:publicationName': 'RIED-Revista Iberoamericana de Educacion a Distancia',
#   'prism:issn': '11382783',
#   'prism:eIssn': '13903306',
#   'prism:volume': '27',
#   'prism:issueIdentifier': '1',
#   'prism:pageRange': '289-318',
#   'prism:coverDate': '2024-01-02',
#   'prism:coverDisplayDate': '2 January 2024',
#   'prism:doi': '10.5944/ried.27.1.37773',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'Universidad de Murcia',
#     'affiliation-city': 'Murcia',
#     'affiliation-country': 'Spain'}],
#   'prism:aggregationType': 'Journal',
#   'subtype': 'ar',
#   'subtypeDescription': 'Article',
#   'source-id': '21101068029',
#   'openaccess': '1',
#   'openaccessFlag': True},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85167979035'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85167979035?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85167979035&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85167979035&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'full-text',
#     '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0360319923037539'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85167979035',
#   'dc:identifier': 'SCOPUS_ID:85167979035',
#   'eid': '2-s2.0-85167979035',
#   'dc:title': 'Zn<inf>1-x</inf>Cu<inf>x</inf>Al<inf>2</inf>O<inf>4</inf> solid solution synthesized by a facile modified sol-gel method for photocatalytic hydrogen generation',
#   'dc:creator': 'Castañeda-Palafox S.J.',
#   'prism:publicationName': 'International Journal of Hydrogen Energy',
#   'prism:issn': '03603199',
#   'prism:volume': '51',
#   'prism:pageRange': '1279-1291',
#   'prism:coverDate': '2024-01-02',
#   'prism:coverDisplayDate': '2 January 2024',
#   'prism:doi': '10.1016/j.ijhydene.2023.07.246',
#   'pii': 'S0360319923037539',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'Centro de Investigaciones en Optica, A.C.',
#     'affiliation-city': 'Leon',
#     'affiliation-country': 'Montenegro'}],
#   'prism:aggregationType': 'Journal',
#   'subtype': 'ar',
#   'subtypeDescription': 'Article',
#   'source-id': '26991',
#   'openaccess': '0',
#   'openaccessFlag': False},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85179918176'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85179918176?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85179918176&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85179918176&origin=inward'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85179918176',
#   'dc:identifier': 'SCOPUS_ID:85179918176',
#   'eid': '2-s2.0-85179918176',
#   'dc:title': 'RESEARCH ON CHEMICAL COMPOUNDS FROM EDIBLE MUSHROOMS FOR THE CONTROL OF GASTROINTESTINAL NEMATODES AND PHYTOPARASITES',
#   'dc:creator': 'Aguilar-Marcelino L.',
#   'prism:publicationName': 'Tropical and Subtropical Agroecosystems',
#   'prism:eIssn': '18700462',
#   'prism:volume': '27',
#   'prism:issueIdentifier': '1',
#   'prism:pageRange': None,
#   'prism:coverDate': '2024-01-01',
#   'prism:coverDisplayDate': 'January 2024',
#   'prism:doi': '10.56369/tsaes.4611',
#   'citedby-count': '0',
#   'prism:aggregationType': 'Journal',
#   'subtype': 'ar',
#   'subtypeDescription': 'Article',
#   'article-number': '011',
#   'source-id': '21100200406',
#   'openaccess': '1',
#   'openaccessFlag': True},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85179697628'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85179697628?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85179697628&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85179697628&origin=inward'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85179697628',
#   'dc:identifier': 'SCOPUS_ID:85179697628',
#   'eid': '2-s2.0-85179697628',
#   'dc:title': 'Analysis of the state of conservation of Trachurus trachurus in the Western Mediterranean Sea based on the interannual (2009–2020) changes in their life history traits',
#   'dc:creator': 'Rodríguez-Castañeda J.C.',
#   'prism:publicationName': 'Marine Biology',
#   'prism:issn': '00253162',
#   'prism:eIssn': '14321793',
#   'prism:volume': '171',
#   'prism:issueIdentifier': '1',
#   'prism:pageRange': None,
#   'prism:coverDate': '2024-01-01',
#   'prism:coverDisplayDate': 'January 2024',
#   'prism:doi': '10.1007/s00227-023-04356-4',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'CSIC-IEO-COB - Centro Oceanográfico de Illes Balears',
#     'affiliation-city': 'Palma',
#     'affiliation-country': 'Spain'},
#    {'@_fa': 'true',
#     'affilname': 'Universitat de les Illes Balears',
#     'affiliation-city': 'Palma',
#     'affiliation-country': 'Spain'}],
#   'prism:aggregationType': 'Journal',
#   'subtype': 'ar',
#   'subtypeDescription': 'Article',
#   'article-number': '34',
#   'source-id': '12165',
#   'openaccess': '1',
#   'openaccessFlag': True},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85178559429'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85178559429?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85178559429&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85178559429&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'full-text',
#     '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0966692323002260'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85178559429',
#   'dc:identifier': 'SCOPUS_ID:85178559429',
#   'eid': '2-s2.0-85178559429',
#   'dc:title': 'Yes, size does matter (for cycling safety)! Comparing behavioral and safety outcomes in S, M, L, and XL cities from 18 countries',
#   'dc:creator': 'Useche S.A.',
#   'prism:publicationName': 'Journal of Transport Geography',
#   'prism:issn': '09666923',
#   'prism:volume': '114',
#   'prism:pageRange': None,
#   'prism:coverDate': '2024-01-01',
#   'prism:coverDisplayDate': 'January 2024',
#   'prism:doi': '10.1016/j.jtrangeo.2023.103754',
#   'pii': 'S0966692323002260',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'Universitat de València',
#     'affiliation-city': 'Valencia',
#     'affiliation-country': 'Spain'}],
#   'prism:aggregationType': 'Journal',
#   'subtype': 'ar',
#   'subtypeDescription': 'Article',
#   'article-number': '103754',
#   'source-id': '29295',
#   'openaccess': '1',
#   'openaccessFlag': True},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85178334533'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85178334533?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85178334533&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85178334533&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'full-text',
#     '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S1043661823003742'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85178334533',
#   'dc:identifier': 'SCOPUS_ID:85178334533',
#   'eid': '2-s2.0-85178334533',
#   'dc:title': 'Powering prescription: Mitochondria as “Living Drugs” – Definition, clinical applications, and industry advancements',
#   'dc:creator': 'Caicedo A.',
#   'prism:publicationName': 'Pharmacological Research',
#   'prism:issn': '10436618',
#   'prism:eIssn': '10961186',
#   'prism:volume': '199',
#   'prism:pageRange': None,
#   'prism:coverDate': '2024-01-01',
#   'prism:coverDisplayDate': 'January 2024',
#   'prism:doi': '10.1016/j.phrs.2023.107018',
#   'pii': 'S1043661823003742',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'Universidad San Francisco de Quito',
#     'affiliation-city': 'Quito',
#     'affiliation-country': 'Ecuador'},
#    {'@_fa': 'true',
#     'affilname': 'Mito-Act Research Consortium',
#     'affiliation-city': 'Quito',
#     'affiliation-country': 'Ecuador'}],
#   'pubmed-id': '38013162',
#   'prism:aggregationType': 'Journal',
#   'subtype': 're',
#   'subtypeDescription': 'Review',
#   'article-number': '107018',
#   'source-id': '21169',
#   'openaccess': '1',
#   'openaccessFlag': True},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85178240746'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85178240746?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85178240746&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85178240746&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'full-text',
#     '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0031942223003382'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85178240746',
#   'dc:identifier': 'SCOPUS_ID:85178240746',
#   'eid': '2-s2.0-85178240746',
#   'dc:title': 'Inhibition of multidrug-resistant MCF-7 breast cancer cells with combinations of clinical drugs and resin glycosides from Operculina hamiltonii',
#   'dc:creator': 'Moreno-Velasco A.',
#   'prism:publicationName': 'Phytochemistry',
#   'prism:issn': '00319422',
#   'prism:volume': '217',
#   'prism:pageRange': None,
#   'prism:coverDate': '2024-01-01',
#   'prism:coverDisplayDate': 'January 2024',
#   'prism:doi': '10.1016/j.phytochem.2023.113922',
#   'pii': 'S0031942223003382',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'Universidad Nacional Autónoma de México, Facultad de Quimica',
#     'affiliation-city': 'Mexico',
#     'affiliation-country': 'Mexico'}],
#   'pubmed-id': '37972675',
#   'prism:aggregationType': 'Journal',
#   'subtype': 'ar',
#   'subtypeDescription': 'Article',
#   'article-number': '113922',
#   'source-id': '16534',
#   'openaccess': '0',
#   'openaccessFlag': False},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85176563742'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85176563742?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85176563742&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85176563742&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'full-text',
#     '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S2603924923000411'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85176563742',
#   'dc:identifier': 'SCOPUS_ID:85176563742',
#   'eid': '2-s2.0-85176563742',
#   'dc:title': 'Neutrophil lymphocyte index as a factor associated with mortality in patients with severe craniocerebral trauma',
#   'dc:creator': 'Vásquez-Tirado G.A.',
#   'prism:publicationName': 'Medicina Clinica Practica',
#   'prism:eIssn': '26039249',
#   'prism:volume': '7',
#   'prism:issueIdentifier': '1',
#   'prism:pageRange': None,
#   'prism:coverDate': '2024-01-01',
#   'prism:coverDisplayDate': '1 January 2024',
#   'prism:doi': '10.1016/j.mcpsp.2023.100403',
#   'pii': 'S2603924923000411',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'Universidad Privada Antenor Orrego',
#     'affiliation-city': 'Trujillo',
#     'affiliation-country': 'Peru'}],
#   'prism:aggregationType': 'Journal',
#   'subtype': 'ar',
#   'subtypeDescription': 'Article',
#   'article-number': '100403',
#   'source-id': '21100904984',
#   'openaccess': '1',
#   'openaccessFlag': True},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85176386752'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85176386752?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85176386752&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85176386752&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'full-text',
#     '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S2212109923000924'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85176386752',
#   'dc:identifier': 'SCOPUS_ID:85176386752',
#   'eid': '2-s2.0-85176386752',
#   'dc:title': 'Study of the Direct Costs of Asthma at a Healthcare Service Provider in Bogotá, Colombia',
#   'dc:creator': 'Gil-Rojas Y.',
#   'prism:publicationName': 'Value in Health Regional Issues',
#   'prism:issn': '22121099',
#   'prism:eIssn': '22121102',
#   'prism:volume': '39',
#   'prism:pageRange': '6-13',
#   'prism:coverDate': '2024-01-01',
#   'prism:coverDisplayDate': 'January 2024',
#   'prism:doi': '10.1016/j.vhri.2023.09.006',
#   'pii': 'S2212109923000924',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'NeuroEconomix',
#     'affiliation-city': 'Bogota',
#     'affiliation-country': 'Colombia'}],
#   'pubmed-id': '37967491',
#   'prism:aggregationType': 'Journal',
#   'subtype': 'ar',
#   'subtypeDescription': 'Article',
#   'source-id': '21100218529',
#   'openaccess': '1',
#   'openaccessFlag': True},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85176010491'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85176010491?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85176010491&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85176010491&origin=inward'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85176010491',
#   'dc:identifier': 'SCOPUS_ID:85176010491',
#   'eid': '2-s2.0-85176010491',
#   'dc:title': 'Simulation Model to Assess Household Water Saving Devices in Bogota City',
#   'dc:creator': 'Chavarro A.',
#   'prism:publicationName': 'Communications in Computer and Information Science',
#   'prism:issn': '18650929',
#   'prism:eIssn': '18650937',
#   'prism:isbn': [{'@_fa': 'true', '$': '9783031468124'}],
#   'prism:volume': '1874 CCIS',
#   'prism:pageRange': '213-228',
#   'prism:coverDate': '2024-01-01',
#   'prism:coverDisplayDate': '2024',
#   'prism:doi': '10.1007/978-3-031-46813-1_15',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'Institution Universitaria Politecnico Grancolombiano',
#     'affiliation-city': 'Bogota',
#     'affiliation-country': 'Colombia'}],
#   'prism:aggregationType': 'Book Series',
#   'subtype': 'cp',
#   'subtypeDescription': 'Conference Paper',
#   'source-id': '17700155007',
#   'openaccess': '0',
#   'openaccessFlag': False},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85175380853'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85175380853?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85175380853&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85175380853&origin=inward'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85175380853',
#   'dc:identifier': 'SCOPUS_ID:85175380853',
#   'eid': '2-s2.0-85175380853',
#   'dc:title': 'Computational assessment of lipid production in Rhodosporidium toruloides\xa0in two-stage and one-stage batch bioprocesses',
#   'dc:creator': 'Castañeda M.T.',
#   'prism:publicationName': 'Biotechnology and Bioengineering',
#   'prism:issn': '00063592',
#   'prism:eIssn': '10970290',
#   'prism:volume': '121',
#   'prism:issueIdentifier': '1',
#   'prism:pageRange': '238-249',
#   'prism:coverDate': '2024-01-01',
#   'prism:coverDisplayDate': 'January 2024',
#   'prism:doi': '10.1002/bit.28579',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'Facultad de Ingeniería, Universidad Nacional de La Plata',
#     'affiliation-city': 'La Plata',
#     'affiliation-country': 'Argentina'}],
#   'pubmed-id': '37902687',
#   'prism:aggregationType': 'Journal',
#   'subtype': 'ar',
#   'subtypeDescription': 'Article',
#   'source-id': '15477',
#   'openaccess': '0',
#   'openaccessFlag': False},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85164344770'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85164344770?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85164344770&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85164344770&origin=inward'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85164344770',
#   'dc:identifier': 'SCOPUS_ID:85164344770',
#   'eid': '2-s2.0-85164344770',
#   'dc:title': 'Plasmids, a molecular cornerstone of antimicrobial resistance in the One Health era',
#   'dc:creator': 'Castañeda-Barba S.',
#   'prism:publicationName': 'Nature Reviews Microbiology',
#   'prism:issn': '17401526',
#   'prism:eIssn': '17401534',
#   'prism:volume': '22',
#   'prism:issueIdentifier': '1',
#   'prism:pageRange': '18-32',
#   'prism:coverDate': '2024-01-01',
#   'prism:coverDisplayDate': 'January 2024',
#   'prism:doi': '10.1038/s41579-023-00926-x',
#   'citedby-count': '4',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'University of Idaho',
#     'affiliation-city': 'Moscow',
#     'affiliation-country': 'United States'}],
#   'pubmed-id': '37430173',
#   'prism:aggregationType': 'Journal',
#   'subtype': 're',
#   'subtypeDescription': 'Review',
#   'source-id': '20313',
#   'openaccess': '0',
#   'openaccessFlag': False},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85140856465'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85140856465?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85140856465&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85140856465&origin=inward'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85140856465',
#   'dc:identifier': 'SCOPUS_ID:85140856465',
#   'eid': '2-s2.0-85140856465',
#   'dc:title': 'Insecticidal effect of metabolites identified in edible mushrooms against Rhyssomatus nigerrimus Fahraeus',
#   'dc:creator': 'Castañeda-Ramírez G.S.',
#   'prism:publicationName': 'Brazilian Journal of Biology',
#   'prism:issn': '15196984',
#   'prism:eIssn': '16784375',
#   'prism:volume': '84',
#   'prism:pageRange': None,
#   'prism:coverDate': '2024-01-01',
#   'prism:coverDisplayDate': '2024',
#   'prism:doi': '10.1590/1519-6984.264786',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'Instituto Nacional de Investigaciones Forestales, Agricolas y Pecuarias',
#     'affiliation-city': 'Santa Catarina',
#     'affiliation-country': 'Mexico'}],
#   'pubmed-id': '36287529',
#   'prism:aggregationType': 'Journal',
#   'subtype': 'ar',
#   'subtypeDescription': 'Article',
#   'article-number': 'e264786',
#   'source-id': '13841',
#   'openaccess': '1',
#   'openaccessFlag': True,
#   'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfullgold'}]},
#   'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Gold'}]}},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85173480609'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85173480609?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85173480609&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85173480609&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'full-text',
#     '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0141813023041417'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85173480609',
#   'dc:identifier': 'SCOPUS_ID:85173480609',
#   'eid': '2-s2.0-85173480609',
#   'dc:title': 'Peptides with biological and technofunctional properties produced by bromelain hydrolysis of proteins from different sources: A review',
#   'dc:creator': 'Tacias-Pascacio V.G.',
#   'prism:publicationName': 'International Journal of Biological Macromolecules',
#   'prism:issn': '01418130',
#   'prism:eIssn': '18790003',
#   'prism:volume': '253',
#   'prism:pageRange': None,
#   'prism:coverDate': '2023-12-31',
#   'prism:coverDisplayDate': '31 December 2023',
#   'prism:doi': '10.1016/j.ijbiomac.2023.127244',
#   'pii': 'S0141813023041417',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'Universidad de Ciencias y Artes de Chiapas',
#     'affiliation-city': 'Tuxtla Gutierrez',
#     'affiliation-country': 'Mexico'}],
#   'pubmed-id': '37806416',
#   'prism:aggregationType': 'Journal',
#   'subtype': 're',
#   'subtypeDescription': 'Review',
#   'article-number': '127244',
#   'source-id': '17544',
#   'openaccess': '0',
#   'openaccessFlag': False},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85177026841'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85177026841?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85177026841&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85177026841&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'full-text',
#     '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S2211124723014821'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85177026841',
#   'dc:identifier': 'SCOPUS_ID:85177026841',
#   'eid': '2-s2.0-85177026841',
#   'dc:title': 'Stabilizing vimentin phosphorylation inhibits stem-like cell properties and metastasis of hybrid epithelial/mesenchymal carcinomas',
#   'dc:creator': 'Kuburich N.A.',
#   'prism:publicationName': 'Cell Reports',
#   'prism:eIssn': '22111247',
#   'prism:volume': '42',
#   'prism:issueIdentifier': '12',
#   'prism:pageRange': None,
#   'prism:coverDate': '2023-12-26',
#   'prism:coverDisplayDate': '26 December 2023',
#   'prism:doi': '10.1016/j.celrep.2023.113470',
#   'pii': 'S2211124723014821',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'The Warren Alpert Medical School',
#     'affiliation-city': 'Providence',
#     'affiliation-country': 'United States'}],
#   'pubmed-id': '37979166',
#   'prism:aggregationType': 'Journal',
#   'subtype': 'ar',
#   'subtypeDescription': 'Article',
#   'article-number': '113470',
#   'source-id': '21100201068',
#   'openaccess': '1',
#   'openaccessFlag': True,
#   'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfullgold'}]},
#   'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Gold'}]}},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85178644389'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85178644389?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85178644389&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85178644389&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'full-text',
#     '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0735109723080233'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85178644389',
#   'dc:identifier': 'SCOPUS_ID:85178644389',
#   'eid': '2-s2.0-85178644389',
#   'dc:title': 'Global Burden of Cardiovascular Diseases and Risks, 1990-2022',
#   'dc:creator': 'Mensah G.A.',
#   'prism:publicationName': 'Journal of the American College of Cardiology',
#   'prism:issn': '07351097',
#   'prism:eIssn': '15583597',
#   'prism:volume': '82',
#   'prism:issueIdentifier': '25',
#   'prism:pageRange': '2350-2473',
#   'prism:coverDate': '2023-12-19',
#   'prism:coverDisplayDate': '19 December 2023',
#   'prism:doi': '10.1016/j.jacc.2023.11.007',
#   'pii': 'S0735109723080233',
#   'citedby-count': '1',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'National Institutes of Health (NIH)',
#     'affiliation-city': 'Bethesda',
#     'affiliation-country': 'United States'},
#    {'@_fa': 'true',
#     'affilname': 'National Heart, Lung, and Blood Institute (NHLBI)',
#     'affiliation-city': 'Bethesda',
#     'affiliation-country': 'United States'},
#    {'@_fa': 'true',
#     'affilname': 'University of Cape Town',
#     'affiliation-city': 'Cape Town',
#     'affiliation-country': 'South Africa'}],
#   'pubmed-id': '38092509',
#   'prism:aggregationType': 'Journal',
#   'subtype': 'ar',
#   'subtypeDescription': 'Article',
#   'source-id': '22401',
#   'openaccess': '0',
#   'openaccessFlag': False},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85178279847'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85178279847?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85178279847&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85178279847&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'full-text',
#     '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S2666166723007025'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85178279847',
#   'dc:identifier': 'SCOPUS_ID:85178279847',
#   'eid': '2-s2.0-85178279847',
#   'dc:title': 'Protocol for establishing primary human lung organoid-derived air-liquid interface cultures from cryopreserved human lung tissue',
#   'dc:creator': 'Castaneda D.C.',
#   'prism:publicationName': 'STAR Protocols',
#   'prism:eIssn': '26661667',
#   'prism:volume': '4',
#   'prism:issueIdentifier': '4',
#   'prism:pageRange': None,
#   'prism:coverDate': '2023-12-15',
#   'prism:coverDisplayDate': '15 December 2023',
#   'prism:doi': '10.1016/j.xpro.2023.102735',
#   'pii': 'S2666166723007025',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'The Jackson Laboratory',
#     'affiliation-city': 'Bar Harbor',
#     'affiliation-country': 'United States'}],
#   'pubmed-id': '37991921',
#   'prism:aggregationType': 'Journal',
#   'subtype': 'ar',
#   'subtypeDescription': 'Article',
#   'article-number': '102735',
#   'source-id': '21101038828',
#   'openaccess': '1',
#   'openaccessFlag': True},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85177791002'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85177791002?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85177791002&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85177791002&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'full-text',
#     '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0950061823036723'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85177791002',
#   'dc:identifier': 'SCOPUS_ID:85177791002',
#   'eid': '2-s2.0-85177791002',
#   'dc:title': 'Impact of Density, relative Humidity, and fiber size on hygrothermal properties of barley straw for building envelopes',
#   'dc:creator': 'Castañeda Múnera J.C.',
#   'prism:publicationName': 'Construction and Building Materials',
#   'prism:issn': '09500618',
#   'prism:volume': '409',
#   'prism:pageRange': None,
#   'prism:coverDate': '2023-12-15',
#   'prism:coverDisplayDate': '15 December 2023',
#   'prism:doi': '10.1016/j.conbuildmat.2023.133954',
#   'pii': 'S0950061823036723',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'Université Laval',
#     'affiliation-city': 'Quebec',
#     'affiliation-country': 'Canada'}],
#   'prism:aggregationType': 'Journal',
#   'subtype': 'ar',
#   'subtypeDescription': 'Article',
#   'article-number': '133954',
#   'source-id': '24443',
#   'openaccess': '1',
#   'openaccessFlag': True},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85152291142'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85152291142?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85152291142&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85152291142&origin=inward'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85152291142',
#   'dc:identifier': 'SCOPUS_ID:85152291142',
#   'eid': '2-s2.0-85152291142',
#   'dc:title': 'Metal-Binding Capacity of Whey-Natural Peptides: Experimental Study and in vitro FRAP-Antioxidant Activity',
#   'dc:creator': 'González-Olivares L.G.',
#   'prism:publicationName': 'Biointerface Research in Applied Chemistry',
#   'prism:eIssn': '20695837',
#   'prism:volume': '13',
#   'prism:issueIdentifier': '6',
#   'prism:pageRange': None,
#   'prism:coverDate': '2023-12-15',
#   'prism:coverDisplayDate': '15 December 2023',
#   'prism:doi': '10.33263/BRIAC136.565',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'Autonomous University of Hidalgo State',
#     'affiliation-city': 'Mineral de la Reforma',
#     'affiliation-country': 'Mexico'}],
#   'prism:aggregationType': 'Journal',
#   'subtype': 'ar',
#   'subtypeDescription': 'Article',
#   'article-number': '565',
#   'source-id': '21100861792',
#   'openaccess': '0',
#   'openaccessFlag': False},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85179646006'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85179646006?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85179646006&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85179646006&origin=inward'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85179646006',
#   'dc:identifier': 'SCOPUS_ID:85179646006',
#   'eid': '2-s2.0-85179646006',
#   'dc:title': 'Short-course combination treatment for experimental chronic Chagas disease',
#   'dc:creator': 'González S.',
#   'prism:publicationName': 'Science translational medicine',
#   'prism:eIssn': '19466242',
#   'prism:volume': '15',
#   'prism:issueIdentifier': '726',
#   'prism:pageRange': 'eadg8105',
#   'prism:coverDate': '2023-12-13',
#   'prism:coverDisplayDate': '13 December 2023',
#   'prism:doi': '10.1126/scitranslmed.adg8105',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'GSK',
#     'affiliation-city': 'Madrid',
#     'affiliation-country': 'Spain'}],
#   'pubmed-id': '38091410',
#   'prism:aggregationType': 'Journal',
#   'subtype': 'ar',
#   'subtypeDescription': 'Article',
#   'source-id': '19700174677',
#   'openaccess': '0',
#   'openaccessFlag': False},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85179642348'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85179642348?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85179642348&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85179642348&origin=inward'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85179642348',
#   'dc:identifier': 'SCOPUS_ID:85179642348',
#   'eid': '2-s2.0-85179642348',
#   'dc:title': 'DNDI-6174 is a preclinical candidate for visceral leishmaniasis that targets the cytochrome bc<inf>1</inf>',
#   'dc:creator': 'Braillard S.',
#   'prism:publicationName': 'Science translational medicine',
#   'prism:eIssn': '19466242',
#   'prism:volume': '15',
#   'prism:issueIdentifier': '726',
#   'prism:pageRange': 'eadh9902',
#   'prism:coverDate': '2023-12-13',
#   'prism:coverDisplayDate': '13 December 2023',
#   'prism:doi': '10.1126/scitranslmed.adh9902',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': '15 Chemin Camille-Vidart',
#     'affiliation-city': 'Geneva',
#     'affiliation-country': 'Switzerland'}],
#   'pubmed-id': '38091406',
#   'prism:aggregationType': 'Journal',
#   'subtype': 'ar',
#   'subtypeDescription': 'Article',
#   'source-id': '19700174677',
#   'openaccess': '0',
#   'openaccessFlag': False},
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85180007347'},
#    {'@_fa': 'true',
#     '@ref': 'author-affiliation',
#     '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85180007347?field=author,affiliation'},
#    {'@_fa': 'true',
#     '@ref': 'scopus',
#     '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85180007347&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85180007347&origin=inward'}],
#   'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85180007347',
#   'dc:identifier': 'SCOPUS_ID:85180007347',
#   'eid': '2-s2.0-85180007347',
#   'dc:title': 'Multi-locus phylogenetic analyses reveal eight novel species of Distoseptispora from southern China',
#   'dc:creator': 'Hu Y.F.',
#   'prism:publicationName': 'Microbiology spectrum',
#   'prism:eIssn': '21650497',
#   'prism:volume': '11',
#   'prism:issueIdentifier': '6',
#   'prism:pageRange': 'e0246823',
#   'prism:coverDate': '2023-12-12',
#   'prism:coverDisplayDate': '12 December 2023',
#   'prism:doi': '10.1128/spectrum.02468-23',
#   'citedby-count': '0',
#   'affiliation': [{'@_fa': 'true',
#     'affilname': 'Jiangxi Agricultural University',
#     'affiliation-city': 'Nanchang',
#     'affiliation-country': 'China'}],
#   'pubmed-id': '37905843',
#   'prism:aggregationType': 'Journal',
#   'subtype': 'ar',
#   'subtypeDescription': 'Article',
#   'source-id': '21100433120',
#   'openaccess': '1',
#   'openaccessFlag': True,
#   'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfullgold'}]},
#   'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Gold'}]}}]

# %%
pd.DataFrame(doc_srch.results).head(2)
# Out:
#    @_fa                                               link  \
# 0  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 1  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
#
#                                            prism:url          dc:identifier  \
# 0  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85179485333
# 1  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85178631266
#
#                   eid                                           dc:title  \
# 0  2-s2.0-85179485333  Brain structural change associated with Cognit...
# 1  2-s2.0-85178631266  Design and optimization methodology for differ...
#
#              dc:creator                              prism:publicationName  \
# 0   González-Alemañy E.                                     Brain Research
# 1  Rodríguez-Reyna S.L.  Journal of the Mechanical Behavior of Biomedic...
#
#   prism:issn prism:eIssn prism:volume prism:pageRange prism:coverDate  \
# 0   00068993    18726240         1825            None      2024-02-15
# 1   17516161    18780180          150            None      2024-02-01
#
#   prism:coverDisplayDate                       prism:doi                pii  \
# 0       15 February 2024  10.1016/j.brainres.2023.148702  S0006899323004730
# 1          February 2024     10.1016/j.jmbbm.2023.106257  S1751616123006100
#
#   citedby-count                                        affiliation pubmed-id  \
# 0             0  [{'@_fa': 'true', 'affilname': 'Cuban Neurosci...  38070819
# 1             0  [{'@_fa': 'true', 'affilname': 'Universidad Au...       NaN
#
#   prism:aggregationType subtype subtypeDescription article-number   source-id  \
# 0               Journal      ar            Article         148702       14346
# 1               Journal      ar            Article         106257  8000153139
#
#   openaccess  openaccessFlag prism:issueIdentifier prism:isbn freetoread  \
# 0          0           False                   NaN        NaN        NaN
# 1          0           False                   NaN        NaN        NaN
#
#   freetoreadLabel
# 0             NaN
# 1             NaN

# %% [markdown]
# Papers from `castaneda` with `behavioral operations` in the keywords and the journal `IJPE`.

# %%
view = 'COMPLETE'
#view = 'STANDARD'
query = "AUTHOR-NAME(castaneda) AND KEY('behavioral operations') AND SRCTITLE('international journal of production economics')"
doc_srch = ElsSearch(query=query, index='scopus')
doc_srch.execute(client, get_all = True, view = view)
print ("doc_srch has", len(doc_srch.results), "results.")
# Out:
# doc_srch has 2 results.

# %%
results_df = pd.DataFrame(doc_srch.results)
results_df
# Out:
#    @_fa                                               link  \
# 0  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 1  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
#
#                                            prism:url          dc:identifier  \
# 0  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85060921433
# 1  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85042908601
#
#                   eid                                           dc:title  \
# 0  2-s2.0-85060921433  A behavioral investigation of supply chain con...
# 1  2-s2.0-85042908601        Ordering behavior in a newsstand experiment
#
#      dc:creator                          prism:publicationName prism:issn  \
# 0  Castañeda J.  International Journal of Production Economics   09255273
# 1  Castañeda J.  International Journal of Production Economics   09255273
#
#   prism:volume prism:pageRange prism:coverDate prism:coverDisplayDate  \
# 0          210           72-83      2019-04-01             April 2019
# 1          197         186-196      2018-03-01           1 March 2018
#
#                     prism:doi                pii  \
# 0  10.1016/j.ijpe.2018.12.024  S0925527318305024
# 1  10.1016/j.ijpe.2017.12.014  S0925527317304206
#
#                                       dc:description citedby-count  \
# 0  The business context in developing economies i...            14
# 1  We study ordering behavior in a multi-item new...            14
#
#                                          affiliation prism:aggregationType  \
# 0  [{'@_fa': 'true', 'affiliation-url': 'https://...               Journal
# 1  [{'@_fa': 'true', 'affiliation-url': 'https://...               Journal
#
#   subtype subtypeDescription                                author-count  \
# 0      ar            Article  {'@limit': '100', '@total': '3', '$': '3'}
# 1      ar            Article  {'@limit': '100', '@total': '2', '$': '2'}
#
#                                               author  \
# 0  [{'@_fa': 'true', '@seq': '1', 'author-url': '...
# 1  [{'@_fa': 'true', '@seq': '1', 'author-url': '...
#
#                                         authkeywords source-id fund-acr  \
# 0  Behavioral operations | Development operations...     19165    USAID
# 1  Behavioral operations | Newsstand problem | Ne...     19165      SNF
#
#               fund-no                                       fund-sponsor  \
# 0  AID-OAA-A-12-00095  United States Agency for International Develop...
# 1       P2TIP1_148341  Schweizerischer Nationalfonds zur Förderung de...
#
#   openaccess  openaccessFlag  \
# 0          1            True
# 1          1            True
#
#                                           freetoread  \
# 0  {'value': [{'$': 'all'}, {'$': 'publisherfree2...
# 1  {'value': [{'$': 'all'}, {'$': 'publisherfree2...
#
#                                      freetoreadLabel
# 0  {'value': [{'$': 'All Open Access'}, {'$': 'Br...
# 1  {'value': [{'$': 'All Open Access'}, {'$': 'Br...

# %%
print(results_df.loc[0,'dc:title'])
# Out:
# A behavioral investigation of supply chain contracts for a newsvendor problem in a developing economy

# %%
print(results_df.loc[0,'dc:description'])
# Out:
# The business context in developing economies introduces challenges in scaling production that are often distinct from those faced in mature economies. This study focuses on the potential for risk-sharing mechanisms to overcome some of those challenges for agricultural supply chains in Uganda. The study follows a two-stage research approach conducted in collaboration with the United Nations World Food Programme (WFP), which supported adoption of hermetic crop storage products such as silos in the country since 2013. In the first stage, through interviews with six artisanal silo manufacturers we identified three constraints in scaling silo production that were accentuated by the newsvendor dynamics in this market. In the second stage, we considered the potential for risk-sharing contracts to help alleviate some of those constraints and explored behavioral explanations to account for differences. We ran a laboratory experiment using two contracts that our interviews suggest are feasible in this business context: a buyback mechanism that allows manufacturers to share the risks of procuring excess metal sheets and a salvage mechanism that allows them to share the risks of over-producing silos. The results reveal a consistent under-ordering across both contracts. They also show that while buyback participants respond to contract prices as existing theory would predict, salvage participants do not. Our study provides insights regarding the potential, and the limitations, of different risk-sharing mechanisms to increase the supply of products in developing economies.

# %%
print(results_df.loc[0,'authkeywords'])
# Out:
# Behavioral operations | Development operations | Food security | Newsvendor problem | Post-harvest storage | Supply chain contracts

# %% [markdown]
# Testing the API in the browser:
#
# ```http
# http://api.elsevier.com/content/search/scopus?query=DOI%28%2210.1021%2Fes052595%2B%22%29&APIKey=36e793b8a1d28cbc4662f2b16160d39c
# ```
#
# ```http
# http://api.elsevier.com/content/search/scopus?query=DOI%28%2210.1021%2Fes052595%2B%22%29&APIKey=36e793b8a1d28cbc4662f2b16160d39c&field=description
# ```
#
# ```http
# https://api.elsevier.com/content/abstract/scopus_id/85060921433?APIKey=36e793b8a1d28cbc4662f2b16160d39c&field=description
# ```

# %% [markdown]
# ### Search exploration for project

# %% [markdown]
# Extract:
# - Title
# - Keywords
# - Abstract
# - Authors
# - Journal
# - Publication year
# - DOI

# %% [markdown]
# #### Search 1
#
# `Behavioral operations` (BeOps) papers published in `Management Science` before `2023`.

# %%
keyword = "\"behavio*ral operations\""
journal = "\"management science\""
query = "KEY(" + keyword + ") AND SRCTITLE(" + journal + ") AND PUBYEAR < 2023"
print(query)
# Out:
# KEY("behavio*ral operations") AND SRCTITLE("management science") AND PUBYEAR < 2023

# %%
view = 'COMPLETE'
#view = 'STANDARD'
doc_srch = ElsSearch(query=query, index='scopus')
doc_srch.execute(client, get_all = True, view = view)
print ("doc_srch has", len(doc_srch.results), "results.")
# Out:
# doc_srch has 57 results.

# %%
results_df = pd.DataFrame(doc_srch.results)
results_df.head(2)
# Out:
#    @_fa                                               link  \
# 0  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 1  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
#
#                                            prism:url          dc:identifier  \
# 0  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85128220259
# 1  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85144576577
#
#                   eid                                           dc:title  \
# 0  2-s2.0-85128220259  Retailer Inventory Sharing in Two-Tier Supply ...
# 1  2-s2.0-85144576577  Social Queues (Cues): Impact of Others' Waitin...
#
#    dc:creator prism:publicationName prism:issn prism:eIssn prism:volume  \
# 0  Davis A.M.    Management Science   00251909    15265501           68
# 1     Ülkü S.    Management Science   00251909    15265501           68
#
#   prism:issueIdentifier prism:pageRange prism:coverDate  \
# 0                    12       8773-8790      2022-12-01
# 1                    11       7958-7976      2022-11-01
#
#   prism:coverDisplayDate               prism:doi  \
# 0          December 2022  10.1287/mnsc.2022.4323
# 1          November 2022  10.1287/mnsc.2021.4282
#
#                                       dc:description citedby-count  \
# 0  When multiple retailers hold inventory to sati...             5
# 1  The traditional queueing literature assumes th...             2
#
#                                          affiliation prism:aggregationType  \
# 0  [{'@_fa': 'true', 'affiliation-url': 'https://...               Journal
# 1  [{'@_fa': 'true', 'affiliation-url': 'https://...               Journal
#
#   subtype subtypeDescription                                author-count  \
# 0      ar            Article  {'@limit': '100', '@total': '3', '$': '3'}
# 1      ar            Article  {'@limit': '100', '@total': '3', '$': '3'}
#
#                                               author  \
# 0  [{'@_fa': 'true', '@seq': '1', 'author-url': '...
# 1  [{'@_fa': 'true', '@seq': '1', 'author-url': '...
#
#                                         authkeywords source-id fund-acr  \
# 0  behavioral operations | inventory sharing | ri...     21307       CU
# 1  behavioral operations | customer behavior | qu...     21307      NaN
#
#      fund-no        fund-sponsor openaccess  openaccessFlag freetoread  \
# 0  undefined  Cornell University          0           False        NaN
# 1  undefined                 NaN          0           False        NaN
#
#   freetoreadLabel pubmed-id
# 0             NaN       NaN
# 1             NaN       NaN

# %%
results_df.loc[0, 'author']
# Out:
# [{'@_fa': 'true',
#   '@seq': '1',
#   'author-url': 'https://api.elsevier.com/content/author/author_id/55724794900',
#   'authid': '55724794900',
#   'orcid': '0000-0002-1689-2299',
#   'authname': 'Davis A.M.',
#   'surname': 'Davis',
#   'given-name': 'Andrew M.',
#   'initials': 'A.M.',
#   'afid': [{'@_fa': 'true', '$': '60116635'}]},
#  {'@_fa': 'true',
#   '@seq': '2',
#   'author-url': 'https://api.elsevier.com/content/author/author_id/57226149331',
#   'authid': '57226149331',
#   'orcid': '0000-0002-6790-6814',
#   'authname': 'Huang R.',
#   'surname': 'Huang',
#   'given-name': 'Rihuan',
#   'initials': 'R.',
#   'afid': [{'@_fa': 'true', '$': '60116635'}]},
#  {'@_fa': 'true',
#   '@seq': '3',
#   'author-url': 'https://api.elsevier.com/content/author/author_id/35615127000',
#   'authid': '35615127000',
#   'orcid': '0000-0002-2026-1780',
#   'authname': 'Thomas D.J.',
#   'surname': 'Thomas',
#   'given-name': 'Douglas J.',
#   'initials': 'D.J.',
#   'afid': [{'@_fa': 'true', '$': '60116392'}]}]

# %% [markdown]
# #### Search 2
#
# `BeOps` manuscripts from `Business, Management and Accounting` that are retrieved from `journals` and were published before `2023`.

# %%
KEY = "\"behavio*ral operations\""
SUBJAREA = 'BUSI'
SRCTYPE = 'j'
PUBYEAR = '2023'
PUBYEAR_OPERATOR = '<'
query = "KEY(" + KEY + ") AND SUBJAREA(" + SUBJAREA + ") AND SRCTYPE(" + SRCTYPE + ") AND PUBYEAR " + PUBYEAR_OPERATOR + " " + PUBYEAR
print(query)
# Out:
# KEY("behavio*ral operations") AND SUBJAREA(BUSI) AND SRCTYPE(j) AND PUBYEAR < 2023

# %%
view = 'COMPLETE'
#view = 'STANDARD'
doc_srch = ElsSearch(query=query, index='scopus')
doc_srch.execute(client, get_all = True, view = view)
print ("doc_srch has", len(doc_srch.results), "results.")
# Out:
# doc_srch has 282 results.

# %%
results_df = pd.DataFrame(doc_srch.results)
results_df.head(2)
# Out:
#    @_fa                                               link  \
# 0  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 1  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
#
#                                            prism:url          dc:identifier  \
# 0  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85141444854
# 1  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85128739402
#
#                   eid                                           dc:title  \
# 0  2-s2.0-85141444854  Pricing decisions for a social comparison prod...
# 1  2-s2.0-85128739402  Quantifying heterogeneity in human behavior: A...
#
#   dc:creator                              prism:publicationName prism:issn  \
# 0   Zhang M.  Transportation Research Part E: Logistics and ...   13665545
# 1   Loske D.                                 Logistics Research   1865035X
#
#   prism:volume prism:pageRange prism:coverDate prism:coverDisplayDate  \
# 0          168            None      2022-12-01          December 2022
# 1           15            1-17      2022-12-01          December 2022
#
#                    prism:doi                pii  \
# 0  10.1016/j.tre.2022.102934  S1366554522003118
# 1            10.23773/2022_1                NaN
#
#                                       dc:description citedby-count  \
# 0  As a natural psychological tendency of human b...             0
# 1  Human operators will remain to play an essenti...             0
#
#                                          affiliation prism:aggregationType  \
# 0  [{'@_fa': 'true', 'affiliation-url': 'https://...               Journal
# 1  [{'@_fa': 'true', 'affiliation-url': 'https://...               Journal
#
#   subtype subtypeDescription                                author-count  \
# 0      ar            Article  {'@limit': '100', '@total': '4', '$': '4'}
# 1      ar            Article  {'@limit': '100', '@total': '3', '$': '3'}
#
#                                               author  \
# 0  [{'@_fa': 'true', '@seq': '1', 'author-url': '...
# 1  [{'@_fa': 'true', '@seq': '1', 'author-url': '...
#
#                                         authkeywords article-number  \
# 0  Behavioral operations management | Pricing dec...         102934
# 1  behavioral operations management | forklift op...              1
#
#      source-id fund-acr    fund-no  \
# 0        20909     NSFC   72071188
# 1  19400158510      NaN  undefined
#
#                                    fund-sponsor openaccess  openaccessFlag  \
# 0  National Natural Science Foundation of China          0           False
# 1                                           NaN          0           False
#
#   prism:eIssn prism:issueIdentifier freetoread freetoreadLabel
# 0         NaN                   NaN        NaN             NaN
# 1    18650368                     1        NaN             NaN

# %% [markdown]
# Let's save the data for further processing without the need to connecting to the API again:
#
# - [Stop using Python strings to represent file paths](https://medium.com/gitconnected/stop-using-python-strings-to-represent-file-paths-7f60bc5479c5)
# - [Python Pathlib is better than the os module for handling files. Here's how to use it](https://builtin.com/software-engineering-perspectives/python-pathlib)
# - [Python Path - How to use the pathlib module with examples](https://www.freecodecamp.org/news/how-to-use-pathlib-module-in-python/)

# %%
# Path object pointing to the project's root
df_path = Path(Path.cwd().parent)

# Path for the CSV file
df_path = df_path.joinpath('data', 'beops_papers.csv')

# Save the search results
# results_df.to_csv(df_path)
